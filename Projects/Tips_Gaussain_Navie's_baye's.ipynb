# %% [markdown]
# #Navies's Baye's therom Algorithm Implementation

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.tail(30)
# Out:
#      total_bill   tip  sex  smoker  day    time  size
# 214       28.17  6.50    1       1    1  Dinner     3
# 215       12.90  1.10    1       1    1  Dinner     2
# 216       28.15  3.00    0       1    1  Dinner     5
# 217       11.59  1.50    0       1    1  Dinner     2
# 218        7.74  1.44    0       1    1  Dinner     2
# 219       30.14  3.09    1       1    1  Dinner     4
# 220       12.16  2.20    0       1    0   Lunch     2
# 221       13.42  3.48    1       1    0   Lunch     2
# 222        8.58  1.92    0       1    0   Lunch     1
# 223       15.98  3.00    1       0    0   Lunch     3
# 224       13.42  1.58    0       1    0   Lunch     2
# 225       16.27  2.50    1       1    0   Lunch     2
# 226       10.09  2.00    1       1    0   Lunch     2
# 227       20.45  3.00    0       0    1  Dinner     4
# 228       13.28  2.72    0       0    1  Dinner     2
# 229       22.12  2.88    1       1    1  Dinner     2
# ...

# %%
df['sex'] = np.where(df['sex']=='Male',0,1)

# %%
df.head()
# Out:
#    total_bill   tip  sex smoker  day    time  size
# 0       16.99  1.01    1     No  Sun  Dinner     2
# 1       10.34  1.66    0     No  Sun  Dinner     3
# 2       21.01  3.50    0     No  Sun  Dinner     3
# 3       23.68  3.31    0     No  Sun  Dinner     2
# 4       24.59  3.61    1     No  Sun  Dinner     4

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['smoker'] = np.where(df['smoker'] == 'No',0,1)

# %%
df.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0  Sun  Dinner     2
# 1       10.34  1.66    0       0  Sun  Dinner     3
# 2       21.01  3.50    0       0  Sun  Dinner     3
# 3       23.68  3.31    0       0  Sun  Dinner     2
# 4       24.59  3.61    1       0  Sun  Dinner     4

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


# Label Encoding
encoder = LabelEncoder()
df['day'] = encoder.fit_transform(df['day'])

print(df)
# Out:
#      total_bill   tip  sex  smoker  day    time  size
# 0         16.99  1.01    1       0    2  Dinner     2
# 1         10.34  1.66    0       0    2  Dinner     3
# 2         21.01  3.50    0       0    2  Dinner     3
# 3         23.68  3.31    0       0    2  Dinner     2
# 4         24.59  3.61    1       0    2  Dinner     4
# ..          ...   ...  ...     ...  ...     ...   ...
# 239       29.03  5.92    0       0    1  Dinner     3
# 240       27.18  2.00    1       1    1  Dinner     2
# 241       22.67  2.00    0       1    1  Dinner     2
# 242       17.82  1.75    0       0    1  Dinner     2
# 243       18.78  3.00    1       0    3  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0    2  Dinner     2
# 1       10.34  1.66    0       0    2  Dinner     3
# 2       21.01  3.50    0       0    2  Dinner     3
# 3       23.68  3.31    0       0    2  Dinner     2
# 4       24.59  3.61    1       0    2  Dinner     4

# %%
X = df.drop('time',axis=1)
X
# Out:
#      total_bill   tip  sex  smoker  day  size
# 0         16.99  1.01    1       0    2     2
# 1         10.34  1.66    0       0    2     3
# 2         21.01  3.50    0       0    2     3
# 3         23.68  3.31    0       0    2     2
# 4         24.59  3.61    1       0    2     4
# ..          ...   ...  ...     ...  ...   ...
# 239       29.03  5.92    0       0    1     3
# 240       27.18  2.00    1       1    1     2
# 241       22.67  2.00    0       1    1     2
# 242       17.82  1.75    0       0    1     2
# 243       18.78  3.00    1       0    3     2
#
# [244 rows x 6 columns]

# %%
y = df['time']
y
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
#train split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,stratify= y,random_state=40)

# %%
X_train.shape,X_test.shape
# Out:
# ((170, 6), (74, 6))

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gass = GaussianNB()

# %%
gass.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred  = gass.predict(X_test)
y_pred
# Out:
# array(['Dinner', 'Lunch', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner',
#        'Lunch', 'Dinner', 'Lunch', 'Dinner', 'Lunch', 'Dinner', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Lunch',
#        'Dinner', 'Lunch', 'Dinner', 'Lunch', 'Lunch', 'Dinner', 'Lunch',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Lunch',
#        'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner', 'Dinner',
#        'Lunch', 'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Dinner', 'Lunch',
#        'Dinner', 'Dinner', 'Dinner', 'Lunch', 'Dinner', 'Dinner',
#        'Dinner', 'Lunch', 'Lunch', 'Dinner', 'Dinner', 'Dinner', 'Dinner',
#        'Dinner', 'Lunch'], dtype='<U6')

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[51  2]
#  [ 2 19]]
# 0.9459459459459459
#               precision    recall  f1-score   support
#
#       Dinner       0.96      0.96      0.96        53
#        Lunch       0.90      0.90      0.90        21
#
#     accuracy                           0.95        74
#    macro avg       0.93      0.93      0.93        74
# weighted avg       0.95      0.95      0.95        74

# %%
#accuracy of dataset
X_train_acc = gass.predict(X_train)
X_train_acc_data = accuracy_score(X_train_acc,Y_train)
print(X_train_acc_data)
# Out:
# 0.6176470588235294

# %%
X_test_acc = gass.predict(X_test)
X_test_acc_data = accuracy_score(X_test_acc,Y_test)
print(X_test_acc_data)
# Out:
# 0.6486486486486487

# %%
input_data = (20.10,4.00,1,1,0,5)

input_numpy  = np.asarray(input_data)

# We need to reshape the array, because we are predicting for one instance

input_reshape = input_numpy.reshape(1,-1)


prediction = gass.predict(input_reshape)
prediction

if (prediction == 'Dinner'):
  print("Yes, This person went for Dinner :",prediction)
else:
  print("No, This person went for Lunch :",prediction)
# Out:
# Yes, This person went for Dinner : ['Dinner']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
